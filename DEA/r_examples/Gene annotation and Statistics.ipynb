# %%
# Установка пакета org.Hs.eg.db, limma
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BioManager::install("org.Hs.eg.db")
BiocManager::install("limma")
# Out:
# Error in parse(text = x, srcfile = src): <text>:9:13: неожиданный '('
# 8: BiocManager::install("oligoData")
# 9: BioManager::(
#                ^
# Traceback:

# %%
# Подключаем библиотеки
library(org.Hs.eg.db)
library(limma)
# Out:
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#
#
#
# Attaching package: ‘limma’
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     plotMA

# %%
# Выводим колонки базы данных org.Hs.eg.db
# В ней каждая колонка означает id гена в какой-либо другой базе данных
# Например, Ensembl, Uniprot, Refseq
# Эти базы даных могут иметь разные назначения, то есть не все базы данных про ген
# Но самое главное, что какждый элемент в этих базах данных имеет id
# Тем самым с помощью org.Hs.eg.db можно сопоставлять id из разных баз
columns(org.Hs.eg.db)
# Out:
#  [1] "ACCNUM"       "ALIAS"        "ENSEMBL"      "ENSEMBLPROT"  "ENSEMBLTRANS"
#  [6] "ENTREZID"     "ENZYME"       "EVIDENCE"     "EVIDENCEALL"  "GENENAME"
# [11] "GO"           "GOALL"        "IPI"          "MAP"          "OMIM"
# [16] "ONTOLOGY"     "ONTOLOGYALL"  "PATH"         "PFAM"         "PMID"
# [21] "PROSITE"      "REFSEQ"       "SYMBOL"       "UCSCKG"       "UNIGENE"
# [26] "UNIPROT"

# %%
# Пример данных
entrez <- c("673", "837")
select(org.Hs.eg.db, keys=entrez,
  keytype="ENTREZID",
  columns=c("SYMBOL"))
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#   ENTREZID SYMBOL
# 1 673      BRAF
# 2 837      CASP4

# %%
select(org.Hs.eg.db, keys=c("GO:0051301"),
  keytype="GO",
  columns=c("SYMBOL"))
# Out:
# 'select()' returned 1:many mapping between keys and columns
#     GO         EVIDENCE ONTOLOGY SYMBOL
# 1   GO:0051301 IEA      BP       BIRC5
# 2   GO:0051301 IEA      BP       ARF6
# 3   GO:0051301 IEA      BP       CCND1
# 4   GO:0051301 IEA      BP       BUB1
# 5   GO:0051301 IEA      BP       BUB1B
# 6   GO:0051301 IEA      BP       CCNA2
# 7   GO:0051301 IEA      BP       CCNB1
# 8   GO:0051301 IEA      BP       CCND2
# 9   GO:0051301 IEA      BP       CCND3
# 10  GO:0051301 IEA      BP       CCNE1
# 11  GO:0051301 IEA      BP       CCNF
# 12  GO:0051301 IEA      BP       CCNG1
# 13  GO:0051301 IEA      BP       CCNG2
# 14  GO:0051301 IEA      BP       CCNT1
# 15  GO:0051301 IEA      BP       CCNT2
# 16  GO:0051301 IEA      BP       CDK1
# 17  GO:0051301 IEA      BP       CDC6
# 18  GO:0051301 IEA      BP       CDC20
# 19  GO:0051301 IEA      BP       CDC25A
# 20  GO:0051301 IEA      BP       CDC25B
# 21  GO:0051301 IEA      BP       CDC25C
# 22  GO:0051301 IEA      BP       CDK2
# 23  GO:0051301 IEA      BP       CDK3
# 24  GO:0051301 IEA      BP       CDK4
# 25  GO:0051301 IEA      BP       CDK5
# 26  GO:0051301 IEA      BP       CDK6
# 27  GO:0051301 IEA      BP       CDK7
# 28  GO:0051301 IEA      BP       CENPC
# 29  GO:0051301 IEA      BP       CENPE
# 30  GO:0051301 IEA      BP       CENPF
# ⋮   ⋮          ⋮        ⋮        ⋮
# 317 GO:0051301 IEA      BP       SPC24
# 318 GO:0051301 IEA      BP       PHF13
# 319 GO:0051301 IEA      BP       PPP1R1C
# 320 GO:0051301 IEA      BP       SGO2
# 321 GO:0051301 IEA      BP       SGO1
# 322 GO:0051301 IEA      BP       SPICE1
# 323 GO:0051301 IEA      BP       CDCA2
# 324 GO:0051301 IEA      BP       SDE2
# 325 GO:0051301 IEA      BP       CENPV
# 326 GO:0051301 IEA      BP       CENPX
# 327 GO:0051301 TAS      BP       TUBB
# 328 GO:0051301 IEA      BP       SENP5
# 329 GO:0051301 IEA      BP       STOX1
# 330 GO:0051301 IEA      BP       CCNY
# 331 GO:0051301 IBA      BP       SKA1
# 332 GO:0051301 IMP      BP       SKA1
# 333 GO:0051301 IEA      BP       REEP3
# 334 GO:0051301 IEA      BP       SKA3
# 335 GO:0051301 IEA      BP       CDC26
# 336 GO:0051301 IEA      BP       HEPACAM2
# 337 GO:0051301 IEA      BP       SYCE2
# 338 GO:0051301 IEA      BP       BOD1L2
# 339 GO:0051301 IEA      BP       NSMCE2
# 340 GO:0051301 IEA      BP       DCDC1
# 341 GO:0051301 IMP      BP       SKA2
# 342 GO:0051301 IEA      BP       NUP43
# 343 GO:0051301 IEA      BP       CENPS
# 344 GO:0051301 IEA      BP       CENPW
# 345 GO:0051301 IEA      BP       KMT5A
# 346 GO:0051301 IEA      BP       SYCE3
